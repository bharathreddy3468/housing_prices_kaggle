# %%
import pandas as pd

# %% [markdown]
# Loading the data

# %%
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/housing_price/train.csv')

# %%
data
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %% [markdown]
# Exploratory data analysis

# %%
data['SalePrice'].isnull().sum()
# Out:
# 0

# %%
n = pd.DataFrame(data.isnull().sum())

# %%
n = n[n[0]>0]
n
# Out:
#                  0
# LotFrontage    259
# Alley         1369
# MasVnrType       8
# MasVnrArea       8
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# Electrical       1
# FireplaceQu    690
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# PoolQC        1453
# Fence         1179
# MiscFeature   1406

# %% [markdown]
# droping all the features which has more than 50% of NaN values

# %%
data = data.drop(['MiscFeature','PoolQC','Fence','Alley'],axis=1)

# %%
n = pd.DataFrame(data.isnull().sum())

# %%
n = n[n[0]>0]
n
# Out:
#                 0
# LotFrontage   259
# MasVnrType      8
# MasVnrArea      8
# BsmtQual       37
# BsmtCond       37
# BsmtExposure   38
# BsmtFinType1   37
# BsmtFinType2   38
# Electrical      1
# FireplaceQu   690
# GarageType     81
# GarageYrBlt    81
# GarageFinish   81
# GarageQual     81
# GarageCond     81

# %% [markdown]
# Now, I'm gonna collect all the categorical values into one list

# %%
#a function which collects all the categorical values
def collect_cat (data):
  list_cat = []
  list_num = []
  for x in data.columns:
    if data[x].dtype == 'O':
      list_cat.append(x)
    else:
      list_num.append(x)
  return list_cat,list_num

# %%
list_cat,list_num = collect_cat(data)

# %%
data['MSSubClass'].value_counts()
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64

# %% [markdown]
# Now, I'll handle the missing data in these features

# %% [markdown]
# i'm doing this column manually because i don't want to impute mode as it may lead to data skewness

# %%
data['FireplaceQu'] = data['FireplaceQu'].fillna('others')

# %%
data['BedroomAbvGr'].values.shape
# Out:
# (1460,)

# %%
def handle_null(data,list_cat,list_num):
  for list_cat in list_cat:
    data[list_cat] = data[list_cat].fillna(str(data[list_cat].mode()[0]))
  for list_num in list_num:
    data[list_num] = data[list_num].fillna((data[list_num]).mode()[0])
  return data

# %%
data = handle_null(data,list_cat,list_num)

# %%
n = pd.DataFrame(data.isnull().sum())

# %%
n = n[n[0]>0]
n
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %%
(data['LotFrontage'].value_counts()).index
# Out:
# Float64Index([ 60.0,  70.0,  80.0,  50.0,  75.0,  65.0,  85.0,  78.0,  21.0,
#                90.0,
#               ...
#               160.0, 168.0, 128.0, 144.0,  39.0, 106.0,  38.0, 138.0, 140.0,
#               137.0],
#              dtype='float64', length=110)

# %% [markdown]
# The nex step is to handle categorical variables

# %%
def handle_cat(data,list_cat):
  for c in list_cat:
    if len(data[c].unique()) > 10:
      n = list(data[c].value_counts().index)[11:]
      data[c] = data[c].replace(n,'others')
  return data

# %%
data = handle_cat(data, list_cat)

# %% [markdown]
# Now i'm gonna handle test data, because all the above steps which we have performed so for on train data,we have to apply for the test data before giving it to the model

# %%
test = pd.read_csv('/content/drive/My Drive/Colab Notebooks/housing_price/test.csv')

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
# 1  1462          20       RL  ...    2010        WD        Normal
# 2  1463          60       RL  ...    2010        WD        Normal
# 3  1464          60       RL  ...    2010        WD        Normal
# 4  1465         120       RL  ...    2010        WD        Normal
#
# [5 rows x 80 columns]

# %%
n = pd.DataFrame(test.isnull().sum())
n = n[n[0]>0]
n
# Out:
#                  0
# MSZoning         4
# LotFrontage    227
# Alley         1352
# Utilities        2
# Exterior1st      1
# Exterior2nd      1
# MasVnrType      16
# MasVnrArea      15
# BsmtQual        44
# BsmtCond        45
# BsmtExposure    44
# BsmtFinType1    42
# BsmtFinSF1       1
# BsmtFinType2    42
# BsmtFinSF2       1
# BsmtUnfSF        1
# TotalBsmtSF      1
# BsmtFullBath     2
# BsmtHalfBath     2
# KitchenQual      1
# Functional       2
# FireplaceQu    730
# GarageType      76
# GarageYrBlt     78
# GarageFinish    78
# GarageCars       1
# GarageArea       1
# GarageQual      78
# GarageCond      78
# PoolQC        1456
# Fence         1169
# MiscFeature   1408
# SaleType         1

# %%
test = test.drop(['MiscFeature','PoolQC','Fence','Alley'],axis=1)

# %%
n = pd.DataFrame(test.isnull().sum())
n = n[n[0]>0]
n
# Out:
#                 0
# MSZoning        4
# LotFrontage   227
# Utilities       2
# Exterior1st     1
# Exterior2nd     1
# MasVnrType     16
# MasVnrArea     15
# BsmtQual       44
# BsmtCond       45
# BsmtExposure   44
# BsmtFinType1   42
# BsmtFinSF1      1
# BsmtFinType2   42
# BsmtFinSF2      1
# BsmtUnfSF       1
# TotalBsmtSF     1
# BsmtFullBath    2
# BsmtHalfBath    2
# KitchenQual     1
# Functional      2
# FireplaceQu   730
# GarageType     76
# GarageYrBlt    78
# GarageFinish   78
# GarageCars      1
# GarageArea      1
# GarageQual     78
# GarageCond     78
# SaleType        1

# %%
(test['FireplaceQu'].value_counts())
# Out:
# Gd    364
# TA    279
# Fa     41
# Po     26
# Ex     19
# Name: FireplaceQu, dtype: int64

# %%
test['FireplaceQu'] = test['FireplaceQu'].fillna('others')

# %%
(test['FireplaceQu'].value_counts())
# Out:
# others    730
# Gd        364
# TA        279
# Fa         41
# Po         26
# Ex         19
# Name: FireplaceQu, dtype: int64

# %%
list_test_cat,list_test_num = collect_cat(test)

# %%
test = handle_null(test,list_test_cat,list_test_num)

# %%
n = pd.DataFrame(test.isnull().sum())
n = n[n[0]>0]
n
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %%
test = handle_cat(test,list_test_cat)

# %%
def handle_unknown(train,test, list_cat,list_test_cat):
  list_1 = []
  for x in list_test_cat:
    list_1 = list(test[x].value_counts().index)
    for q in list_cat:
          for y in list_1:
              if y  not in list(train[q].value_counts().index):
                test[x] = test[x].replace(y,'others')
  return test

# %%
test
# Out:
#         Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0     1461          20       RH  ...    2010        WD        Normal
# 1     1462          20       RL  ...    2010        WD        Normal
# 2     1463          60       RL  ...    2010        WD        Normal
# 3     1464          60       RL  ...    2010        WD        Normal
# 4     1465         120       RL  ...    2010        WD        Normal
# ...    ...         ...      ...  ...     ...       ...           ...
# 1454  2915         160       RM  ...    2006        WD        Normal
# 1455  2916         160       RM  ...    2006        WD       Abnorml
# 1456  2917          20       RL  ...    2006        WD       Abnorml
# 1457  2918          85       RL  ...    2006        WD        Normal
# 1458  2919          60       RL  ...    2006        WD        Normal
#
# [1459 rows x 76 columns]

# %%
data_1 = data.drop(['SalePrice'],axis=1)

# %%
data['SalePrice'].shape
# Out:
# (1460,)

# %%
train_df = pd.concat([data_1,test],axis=0)

# %% [markdown]
# here I concatinated both train and test data because in some categorical columns there are different values which may lead to different columns when we use get dummies method.so in order get same columns i concatinated and called get dummies method

# %%
train_df
# Out:
#         Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0        1          60       RL  ...    2008        WD        Normal
# 1        2          20       RL  ...    2007        WD        Normal
# 2        3          60       RL  ...    2008        WD        Normal
# 3        4          70       RL  ...    2006        WD       Abnorml
# 4        5          60       RL  ...    2008        WD        Normal
# ...    ...         ...      ...  ...     ...       ...           ...
# 1454  2915         160       RM  ...    2006        WD        Normal
# 1455  2916         160       RM  ...    2006        WD       Abnorml
# 1456  2917          20       RL  ...    2006        WD       Abnorml
# 1457  2918          85       RL  ...    2006        WD        Normal
# 1458  2919          60       RL  ...    2006        WD        Normal
#
# [2919 rows x 76 columns]

# %%
train_df['LotFrontage'].dtype
# Out:
# dtype('float64')

# %%
n = pd.DataFrame(train_df.isnull().sum())
n = n[n[0]>0]
n
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %%
train_df = pd.get_dummies(train_df,drop_first=True)

# %%
df_train = train_df[train_df['Id']<=1460]

# %%
df_train
# Out:
#         Id  MSSubClass  ...  SaleCondition_Normal  SaleCondition_Partial
# 0        1          60  ...                     1                      0
# 1        2          20  ...                     1                      0
# 2        3          60  ...                     1                      0
# 3        4          70  ...                     0                      0
# 4        5          60  ...                     1                      0
# ...    ...         ...  ...                   ...                    ...
# 1455  1456          60  ...                     1                      0
# 1456  1457          20  ...                     1                      0
# 1457  1458          70  ...                     1                      0
# 1458  1459          20  ...                     1                      0
# 1459  1460          20  ...                     1                      0
#
# [1460 rows x 220 columns]

# %%
df_test = train_df[train_df['Id']>1460]

# %%
df_test
# Out:
#         Id  MSSubClass  ...  SaleCondition_Normal  SaleCondition_Partial
# 0     1461          20  ...                     1                      0
# 1     1462          20  ...                     1                      0
# 2     1463          60  ...                     1                      0
# 3     1464          60  ...                     1                      0
# 4     1465         120  ...                     1                      0
# ...    ...         ...  ...                   ...                    ...
# 1454  2915         160  ...                     1                      0
# 1455  2916         160  ...                     0                      0
# 1456  2917          20  ...                     0                      0
# 1457  2918          85  ...                     1                      0
# 1458  2919          60  ...                     1                      0
#
# [1459 rows x 220 columns]

# %%
data['SalePrice'].shape
# Out:
# (1460,)

# %%
y_train = data['SalePrice']

# %%
y_train
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
df_train
# Out:
#         Id  MSSubClass  ...  SaleCondition_Normal  SaleCondition_Partial
# 0        1          60  ...                     1                      0
# 1        2          20  ...                     1                      0
# 2        3          60  ...                     1                      0
# 3        4          70  ...                     0                      0
# 4        5          60  ...                     1                      0
# ...    ...         ...  ...                   ...                    ...
# 1455  1456          60  ...                     1                      0
# 1456  1457          20  ...                     1                      0
# 1457  1458          70  ...                     1                      0
# 1458  1459          20  ...                     1                      0
# 1459  1460          20  ...                     1                      0
#
# [1460 rows x 220 columns]

# %% [markdown]
# building the model

# %%
from xgboost.sklearn import XGBRegressor
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import r2_score,mean_squared_error

# %%
y_train.shape
# Out:
# (1460,)

# %%
x_train = df_train.copy()

# %%
xgb1 = XGBRegressor()
parameters = {'nthread':[4], #when use hyperthread, xgboost may become slower
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], #so called `eta` value
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}

xgb_grid = GridSearchCV(xgb1,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)

# %%
xgb_grid.fit(x_train,y_train)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  18 out of  18 | elapsed:   59.2s finished
# GridSearchCV(cv=2, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_...
#                                     scale_pos_weight=1, seed=None, silent=None,
# ...

# %%
var = pd.DataFrame(xgb_grid.cv_results_)

# %%
var
# Out:
#    mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0      13.126556      0.072492  ...        0.005268                1
# 1      14.468881      0.354396  ...        0.007421                3
# 2      17.690817      0.580682  ...        0.007464                2
# 3      13.052685      0.276275  ...        0.012137                6
# 4      15.382524      0.478106  ...        0.013423                8
# 5      17.856383      0.089681  ...        0.011893                7
# 6      12.464686      0.071296  ...        0.006618                4
# 7      12.754383      1.972987  ...        0.008097                5
# 8      10.719340      0.456676  ...        0.009904                9
#
# [9 rows x 19 columns]

# %%
xgb_grid.best_score_
# Out:
# 0.8733865435070007

# %%
xgb_grid.best_params_
# Out:
# {'colsample_bytree': 0.7,
#  'learning_rate': 0.03,
#  'max_depth': 5,
#  'min_child_weight': 4,
#  'n_estimators': 500,
#  'nthread': 4,
#  'objective': 'reg:linear',
#  'silent': 1,
#  'subsample': 0.7}

# %%
xgb1 = XGBRegressor(max_depth='5',learning_rate='0.03',n_estimators=500,min_child_weight=4,silent=1,subsample=0.7,nthread=4,colsample_bytree='0.7',objective='reg:linear')

# %%
xgb1.fit(x_train,y_train)
# Out:
# [09:37:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
df_test.shape
# Out:
# (1459, 220)

# %%
preds =list(xgb1.predict(df_test))

# %%
len(preds)
# Out:
# 1459

# %%
x = pd.DataFrame(df_test['Id'])

# %%
x
# Out:
#         Id
# 0     1461
# 1     1462
# 2     1463
# 3     1464
# 4     1465
# ...    ...
# 1454  2915
# 1455  2916
# 1456  2917
# 1457  2918
# 1458  2919
#
# [1459 rows x 1 columns]

# %%
x['SalePrice'] = preds

# %% [markdown]
# creating the submission file for kaggle predictions

# %%
x.to_csv('/content/drive/My Drive/Colab Notebooks/housing_price/submission.csv',index=False)
